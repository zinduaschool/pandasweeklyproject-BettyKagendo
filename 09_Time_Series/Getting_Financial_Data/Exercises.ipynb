# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install yfinance
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import libraries
import yfinance as yf
import pandas as pd

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stocks = [ 'AAPL', 'TSLA', 'TWTR', 'IBM', 'LNKD']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
stock_data = yf.download(stocks, start = '2015-01-01', end ='2024-06-24')
stock_data.head()
# Out:
# [*******************   40%%                      ]  2 of 5 completed
# $LNKD: possibly delisted; No price data found  (1d 2015-01-01 -> 2024-06-24)
# [*********************100%%**********************]  5 of 5 completed
#
# 2 Failed downloads:
# ['TWTR']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ['LNKD']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2015-01-01 -> 2024-06-24)')
# Price       Adj Close                                       Close              \
# Ticker           AAPL         IBM LNKD       TSLA TWTR       AAPL         IBM
# Date
# 2015-01-02  24.402168  102.338921  NaN  14.620667  NaN  27.332500  154.933075
# 2015-01-05  23.714725  100.728630  NaN  14.006000  NaN  26.562500  152.495224
# 2015-01-06  23.716957   98.556282  NaN  14.085333  NaN  26.565001  149.206497
# 2015-01-07  24.049519   97.912186  NaN  14.063333  NaN  26.937500  148.231354
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2383 entries, 2015-01-02 to 2024-06-21
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2383 non-null   float64
#  1   (Adj Close, IBM)   2383 non-null   float64
#  2   (Adj Close, LNKD)  0 non-null      float64
#  3   (Adj Close, TSLA)  2383 non-null   float64
#  4   (Adj Close, TWTR)  0 non-null      float64
#  5   (Close, AAPL)      2383 non-null   float64
#  6   (Close, IBM)       2383 non-null   float64
#  7   (Close, LNKD)      0 non-null      float64
#  8   (Close, TSLA)      2383 non-null   float64
#  9   (Close, TWTR)      0 non-null      float64
#  10  (High, AAPL)       2383 non-null   float64
#  11  (High, IBM)        2383 non-null   float64
#  12  (High, LNKD)       0 non-null      float64
#  13  (High, TSLA)       2383 non-null   float64
#  14  (High, TWTR)       0 non-null      float64
# ...

# %%
stock_data.dtypes
# Out:
# Price      Ticker
# Adj Close  AAPL      float64
#            IBM       float64
#            LNKD      float64
#            TSLA      float64
#            TWTR      float64
# Close      AAPL      float64
#            IBM       float64
#            LNKD      float64
#            TSLA      float64
#            TWTR      float64
# High       AAPL      float64
#            IBM       float64
#            LNKD      float64
#            TSLA      float64
#            TWTR      float64
# Low        AAPL      float64
#            IBM       float64
#            LNKD      float64
#            TSLA      float64
#            TWTR      float64
# Open       AAPL      float64
#            IBM       float64
#            LNKD      float64
#            TSLA      float64
#            TWTR      float64
# Volume     AAPL        int64
#            IBM         int64
#            LNKD      float64
#            TSLA        int64
#            TWTR      float64
# dtype: object

# %%
stock_data.shape
# Out:
# (2383, 30)

# %%
stock_data.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close', 'LNKD'),
#             ('Adj Close', 'TSLA'),
#             ('Adj Close', 'TWTR'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'IBM'),
#             (    'Close', 'LNKD'),
#             (    'Close', 'TSLA'),
#             (    'Close', 'TWTR'),
#             (     'High', 'AAPL'),
#             (     'High',  'IBM'),
#             (     'High', 'LNKD'),
#             (     'High', 'TSLA'),
#             (     'High', 'TWTR'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'IBM'),
#             (      'Low', 'LNKD'),
#             (      'Low', 'TSLA'),
#             (      'Low', 'TWTR'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'IBM'),
#             (     'Open', 'LNKD'),
#             (     'Open', 'TSLA'),
#             (     'Open', 'TWTR'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'IBM'),
# ...

# %%
stock_data.describe()
# Out:
# Price     Adj Close                                            Close  \
# Ticker         AAPL          IBM LNKD         TSLA TWTR         AAPL
# count   2383.000000  2383.000000  0.0  2383.000000  0.0  2383.000000
# mean      86.985334   112.382260  NaN   106.966508  NaN    88.972270
# std       59.235205    20.102295  NaN   109.676434  NaN    58.782256
# min       20.744020    73.761398  NaN     9.578000  NaN    22.584999
# 25%       33.958483   100.831562  NaN    16.901333  NaN    36.258749
# 50%       54.287514   106.853508  NaN    23.760668  NaN    56.717499
# 75%      145.428299   119.171410  NaN   209.533333  NaN   147.065002
# max      216.669998   195.835968  NaN   409.970001  NaN   216.669998
#
# Price                                       ...         Open               \
# Ticker          IBM LNKD         TSLA TWTR  ...         AAPL          IBM
# count   2383.000000  0.0  2383.000000  0.0  ...  2383.000000  2383.000000
# ...

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
stock_data.items
# Out:
# <bound method DataFrame.items of Price        Adj Close                                         Close  \
# Ticker            AAPL         IBM LNKD        TSLA TWTR        AAPL
# Date
# 2015-01-02   24.402168  102.338921  NaN   14.620667  NaN   27.332500
# 2015-01-05   23.714725  100.728630  NaN   14.006000  NaN   26.562500
# 2015-01-06   23.716957   98.556282  NaN   14.085333  NaN   26.565001
# 2015-01-07   24.049519   97.912186  NaN   14.063333  NaN   26.937500
# 2015-01-08   24.973560  100.040306  NaN   14.041333  NaN   27.972500
# ...                ...         ...  ...         ...  ...         ...
# 2024-06-14  212.490005  169.210007  NaN  178.009995  NaN  212.490005
# 2024-06-17  216.669998  169.500000  NaN  187.440002  NaN  216.669998
# 2024-06-18  214.289993  170.550003  NaN  184.860001  NaN  214.289993
# 2024-06-20  209.679993  173.919998  NaN  181.570007  NaN  209.679993
# 2024-06-21  207.490005  172.460007  NaN  183.009995  NaN  207.490005
#
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = stock_data['Volume']
vol.head(-5)
# Out:
# Ticker           AAPL      IBM  LNKD       TSLA  TWTR
# Date
# 2015-01-02  212818400  5779673   NaN   71466000   NaN
# 2015-01-05  257142000  5104898   NaN   80527500   NaN
# 2015-01-06  263188400  6429448   NaN   93928500   NaN
# 2015-01-07  160423600  4918083   NaN   44526000   NaN
# 2015-01-08  237458000  4431693   NaN   51637500   NaN
# ...               ...      ...   ...        ...   ...
# 2024-06-07   53103900  3475500   NaN   56244900   NaN
# 2024-06-10   97262100  3444700   NaN   50869700   NaN
# 2024-06-11  172373300  2951300   NaN   64761900   NaN
# 2024-06-12  198134300  3522700   NaN   90389400   NaN
# 2024-06-13   97862700  3525700   NaN  118984100   NaN
#
# [2378 rows x 5 columns]

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol['week'] = vol.index.isocalendar().week
vol['year'] = vol.index.year

week = vol.groupby(['week', 'year']).sum()
week.head(16)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3172\1856023458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vol['week'] = vol.index.isocalendar().week
# C:\Users\hp\AppData\Local\Temp\ipykernel_3172\1856023458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vol['year'] = vol.index.year
# Ticker           AAPL       IBM  LNKD        TSLA  TWTR
# week year
# 1    2015   212818400   5779673   0.0    71466000   0.0
#      2016  1375160800  26415265   0.0   314631000   0.0
# ...

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
stock_data_2015 = stock_data[stock_data.index.year == 2015]
total_volume_2015 = stock_data_2015['Volume'].sum()
total_volume_2015
# Out:
# Ticker
# AAPL    5.226420e+10
# IBM     1.156439e+09
# LNKD    0.000000e+00
# TSLA    1.632327e+10
# TWTR    0.000000e+00
# dtype: float64

# %% [markdown]
# ### BONUS: Create your own question and answer it.
